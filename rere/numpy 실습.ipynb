# %% [markdown]
# ###  아래 가이드에 따라서 1000명의 고객 구매데이터를 생성하고 아래사항을 수행하세요(관측치 10000개)
#
# #### Q1. 고객 속성(id, 성별, 연령, 거주지역) 데이터와 거래 데이터를 통합한 데이터 프레임 df를 생성하세요.
# 고객별 속성 데이터
# - id : 1 ~ 1000 고객 번호
# - gender : 0,1 정수 난수 생성
# - age : 0 ~ 80사이 정수 난수 생성
# - region : 1 ~ 10 사이 정수 난수 생성
#
# 거래 데이터
# - no : 1 ~ 10000번 일련번호
# - day : 요일
# - date : 2020-01-01 ~ 2021-12-31 사이의 날짜 1000개 생성
# - product_20 : 고가제품(10), 중가제품(20), 저가제품(30)로 구분제품코드 10 ~ 30
# - product_21 : 고가제품(10), 중가제품(20), 저가제품(30)로 구분제품코드 10 ~ 30
# - price_20 : 1000 ~ 50000 사이 실수 난수 생성
# - price_21 : 1000 ~ 50000 사이 실수 난수 생성
# - quantity_20 : 1 ~ 100 사이 정수 난수 생성
# - quantity_21 : 1 ~ 100 사이 정수 난수 생성
# - time_20 : 01 ~ 24 사이 정수 난수 생성
# - time_21 : 01 ~ 24 사이 정수 난수 생성
# - amount_20 : price_20 * quantity_21
# - amount_21 : price_21 * quantity_21
#
# #### Q2. df를 수정하여 5가지 이상의 인사이트를 포함한 데이터 셋으로 변환하세요
#
# #### Q3. df 를 탐색적 분석을 통하여 인사이트를 도출하세요.

# %%
# 고객별 속성 데이터 생성
import numpy as np
import pandas as pd
import random

random.seed(1)
cusid = np.arange(1,1001)
cusno = np.arange(1,1001)
gender = np.random.randint(0,2,size = 1000)
age = np.random.randint(10,81,size = 1000)
region = np.random.randint(1,11,size=1000)


id = pd.Series(cusid)
cusno = pd.Series(cusno)
gender = pd.Series(gender)
age = pd.Series(age)
region = pd.Series(region)
df = pd.concat([id,cusno,gender,age,region],axis=1)
df.columns = ['cusid','cusno','gender','age','region']
df
# Out:
#      cusid  cusno  gender  age  region
# 0        1      1       1   51       2
# 1        2      2       0   80       8
# 2        3      3       0   41       9
# 3        4      4       1   51       8
# 4        5      5       0   24       3
# ..     ...    ...     ...  ...     ...
# 995    996    996       1   47       6
# 996    997    997       1   34       9
# 997    998    998       1   61      10
# 998    999    999       0   71       1
# 999   1000   1000       1   23       8
#
# [1000 rows x 5 columns]

# %%
df1 = pd.DataFrame(columns=['cusno','date','day','product_20','product_21','price_20','price_21','quantity_20','quantity_21','time_20','time_21','amount_20','amount_21'])
df1
# Out:
# Empty DataFrame
# Columns: [cusno, date, day, product_20, product_21, price_20, price_21, quantity_20, quantity_21, time_20, time_21, amount_20, amount_21]
# Index: []

# %%
# 거래 데이터 생성
random.seed(1)
cusno=np.random.randint(1,1001,size = 10000)
date = pd.date_range(start = '2020-01-01', end = '2021-12-31', freq = 'D') # 1000개 만들기
random_date = [random.choice(date.tolist()) for _ in range(10000)]
day = [x.day_name() for x in random_date]
product_20 = np.random.choice([10,20,30],10000)
product_21 = np.random.choice([10,20,30],10000)
price_20 = np.random.uniform(1000,50000,10000).round(2)
price_21 = np.random.uniform(1000,50000,10000).round(2)
quantity_20 = np.random.randint(1,101,size = 10000)
quantity_21 = np.random.randint(1,101,size = 10000)
time_20 = np.random.randint(1,25,10000)
time_21 = np.random.randint(1,25,10000)
amount_20 = (price_20 * quantity_20).round(2)
amount_21 = (price_21 * quantity_21).round(2)

# %%
df1['cusno'] = cusno
df1['date'] = pd.DataFrame(random_date)
df1['day'] = pd.DataFrame(day)
df1['product_20'] = pd.DataFrame(product_20)

# %%
df1['product_21'] = pd.DataFrame(product_21)
df1['price_20'] =pd.DataFrame(price_20)
df1['price_21'] = pd.DataFrame(price_21)
df1['quantity_20'] = pd.DataFrame(quantity_20)
df1['quantity_21'] = pd.DataFrame(quantity_21)
df1['time_20'] = pd.DataFrame(time_20)
df1['time_21'] = pd.DataFrame(time_21)
df1['amount_20'] = pd.DataFrame(amount_20)
df1['amount_21'] = pd.DataFrame(amount_21)

# %%
df
# Out:
#      cusid  cusno  gender  age  region
# 0        1      1       0   44       7
# 1        2      2       1   27       9
# 2        3      3       1   70       4
# 3        4      4       0   32       8
# 4        5      5       0   64       4
# ..     ...    ...     ...  ...     ...
# 995    996    996       0   75      10
# 996    997    997       0   55       7
# 997    998    998       1   29       1
# 998    999    999       0   34      10
# 999   1000   1000       0   66       5
#
# [1000 rows x 5 columns]

# %%
df1
# Out:
#       cusno       date        day  product_20  product_21  price_20  price_21  \
# 0       776 2020-05-17     Sunday          10          30  23823.46  18362.60
# 1       436 2021-08-05   Thursday          20          20  44677.05  43421.17
# 2       767 2020-03-05   Thursday          20          30  20260.71  32882.42
# 3       307 2020-09-18     Friday          30          10  26491.16  37788.48
# 4       157 2020-04-30   Thursday          30          10  44524.39   1858.69
# ...     ...        ...        ...         ...         ...       ...       ...
# 9995    347 2021-11-28     Sunday          30          30  28102.12  42160.76
# 9996     92 2020-04-22  Wednesday          30          10  43575.07  16970.14
# 9997    228 2021-04-17   Saturday          20          10  35501.80  17219.22
# 9998    396 2020-06-08     Monday          10          30  35580.75  10374.27
# 9999    588 2021-02-03  Wednesday          30          30  26714.11  37165.70
#
#       quantity_20  quantity_21  time_20  time_21   amount_20   amount_21
# 0              76            3        5        4  1810582.96    55087.80
# 1              85            8       17       10  3797549.25   347369.36
# 2              58            8        3        7  1175121.18   263059.36
# 3              16           26        2        1   423858.56   982500.48
# 4              77           13        4       18  3428378.03    24162.97
# ...           ...          ...      ...      ...         ...         ...
# 9995           97           52       10       14  2725905.64  2192359.52
# 9996           33           10       15       11  1437977.31   169701.40
# 9997           95           37       13        1  3372671.00   637111.14
# 9998           65           78        5        8  2312748.75   809193.06
# 9999           36           55       23        4   961707.96  2044113.50
#
# [10000 rows x 13 columns]

# %%
merge_df = pd.merge(df, df1, on='cusno', how='outer')
merge_df
# Out:
#       cusid  cusno  gender  age  region       date        day  product_20  \
# 0         1      1       1   51       2 2021-07-08   Thursday          30
# 1         1      1       1   51       2 2021-11-14     Sunday          20
# 2         1      1       1   51       2 2021-11-15     Monday          20
# 3         1      1       1   51       2 2021-09-17     Friday          30
# 4         2      2       0   80       8 2020-06-24  Wednesday          10
# ...     ...    ...     ...  ...     ...        ...        ...         ...
# 9995   1000   1000       1   23       8 2020-11-02     Monday          30
# 9996   1000   1000       1   23       8 2021-05-30     Sunday          10
# 9997   1000   1000       1   23       8 2021-09-13     Monday          20
# 9998   1000   1000       1   23       8 2020-12-26   Saturday          30
# 9999   1000   1000       1   23       8 2020-04-01  Wednesday          30
#
#       product_21  price_20  price_21  quantity_20  quantity_21  time_20  \
# 0             30  49251.59   8541.46            9           94        5
# 1             20  29042.50  41080.86           12           96       14
# 2             30  41725.05  49417.88            9            9        5
# 3             30  23379.83  40751.26           77           61       15
# 4             10  33982.46   4856.30           72           12        2
# ...          ...       ...       ...          ...          ...      ...
# 9995          10  32531.12  46951.40            8           52       15
# 9996          30  10933.35  26551.07           70            4       15
# 9997          30   7386.91   5472.54           42           67       19
# 9998          30  19707.79   1193.20           98           97       19
# 9999          30  22917.90  25845.20           12           78       16
#
#       time_21   amount_20   amount_21
# 0           7   443264.31   802897.24
# 1           8   348510.00  3943762.56
# 2          20   375525.45   444760.92
# 3          11  1800246.91  2485826.86
# 4          16  2446737.12    58275.60
# ...       ...         ...         ...
# 9995       12   260248.96  2441472.80
# 9996       12   765334.50   106204.28
# 9997       23   310250.22   366660.18
# 9998        8  1931363.42   115740.40
# 9999       14   275014.80  2015925.60
#
# [10000 rows x 17 columns]

# %%
merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   cusid        10000 non-null  int64
#  1   cusno        10000 non-null  int64
#  2   gender       10000 non-null  int64
#  3   age          10000 non-null  int64
#  4   region       10000 non-null  int64
#  5   date         10000 non-null  datetime64[ns]
#  6   day          10000 non-null  object
#  7   product_20   10000 non-null  int64
#  8   product_21   10000 non-null  int64
#  9   price_20     10000 non-null  float64
#  10  price_21     10000 non-null  float64
#  11  quantity_20  10000 non-null  int64
#  12  quantity_21  10000 non-null  int64
#  13  time_20      10000 non-null  int64
#  14  time_21      10000 non-null  int64
#  15  amount_20    10000 non-null  float64
#  16  amount_21    10000 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(11), object(1)
# memory usage: 1.3+ MB

# %%
merge_df.describe()
# Out:
#               cusid         cusno        gender           age        region  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean     503.828600    503.828600      0.512600     45.115200      5.600600
# min        1.000000      1.000000      0.000000     10.000000      1.000000
# 25%      258.000000    258.000000      0.000000     27.000000      3.000000
# 50%      504.000000    504.000000      1.000000     46.000000      6.000000
# 75%      756.250000    756.250000      1.000000     64.000000      8.000000
# max     1000.000000   1000.000000      1.000000     80.000000     10.000000
# std      288.851221    288.851221      0.499866     21.084022      2.829502
#
#                              date   product_20    product_21      price_20  \
# count                       10000  10000.00000  10000.000000  10000.000000
# mean   2020-12-31 07:39:21.600000     19.98300     19.915000  25502.530434
# min           2020-01-01 00:00:00     10.00000     10.000000   1000.170000
# 25%           2020-07-01 00:00:00     10.00000     10.000000  13354.965000
# 50%           2021-01-02 00:00:00     20.00000     20.000000  25589.575000
# 75%           2021-07-02 00:00:00     30.00000     30.000000  37647.215000
# max           2021-12-31 00:00:00     30.00000     30.000000  49999.960000
# std                           NaN      8.16066      8.166361  14056.679224
#
#            price_21   quantity_20   quantity_21       time_20       time_21  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean   25516.910262     50.572000     50.572500     12.419600     12.494000
# min     1000.280000      1.000000      1.000000      1.000000      1.000000
# 25%    13206.022500     25.000000     26.000000      6.000000      6.000000
# 50%    25358.295000     50.500000     50.000000     12.000000     13.000000
# 75%    37705.835000     76.000000     76.000000     18.000000     19.000000
# max    49999.340000    100.000000    100.000000     24.000000     24.000000
# std    14155.407440     28.831797     28.920183      6.917754      6.968402
#
#           amount_20     amount_21
# count  1.000000e+04  1.000000e+04
# mean   1.289493e+06  1.290986e+06
# min    1.831970e+03  2.362530e+03
# 25%    3.859294e+05  3.718032e+05
# 50%    9.892022e+05  9.743217e+05
# 75%    1.961318e+06  1.965702e+06
# max    4.986081e+06  4.946247e+06
# std    1.095052e+06  1.106387e+06

# %%
# 결측치 확인
merge_df.isnull().sum()
# Out:
# cusid          0
# cusno          0
# gender         0
# age            0
# region         0
# date           0
# day            0
# product_20     0
# product_21     0
# price_20       0
# price_21       0
# quantity_20    0
# quantity_21    0
# time_20        0
# time_21        0
# amount_20      0
# amount_21      0
# dtype: int64

# %%
merge_df['total'] = merge_df['amount_20'] + merge_df['amount_21']

# %%
# insight 1

# 나이별 구매 금액 평균
amount_by_age =merge_df.pivot_table(values=['amount_20', 'amount_21','total'], index='age', aggfunc='mean').round(2)
amount_by_age
# Out:
#       amount_20   amount_21       total
# age
# 10   1314531.71  1379911.79  2694443.50
# 11   1039475.82  1302958.37  2342434.19
# 12   1298102.86  1242655.90  2540758.76
# 13   1157118.23  1247238.65  2404356.88
# 14   1492806.56  1402565.26  2895371.81
# ..          ...         ...         ...
# 76   1362466.22  1379987.84  2742454.06
# 77   1321528.21  1243581.83  2565110.04
# 78   1262191.69  1267818.32  2530010.01
# 79   1141946.44  1204232.84  2346179.28
# 80   1400186.77  1264834.41  2665021.17
#
# [71 rows x 3 columns]

# %%
# 파악 하기 어려우므로 10대,20대..로 범주 나누기
bins = [10,20,30,40,50,60,70,80,90]
labels=['teenagers','twenties','thirties','forties','fifties','sixties','seventies','eighties']
# right=False 왼쪽 경계는 포함하고 오른쪽 경계는 미포함
merge_df['age_cat'] = pd.cut(merge_df['age'],bins=bins,labels =labels,right=False)

# %%
amount_by_age =merge_df.pivot_table(values=['amount_20', 'amount_21','total'], index='age_cat', aggfunc='mean').round()
amount_by_age=amount_by_age.rename(columns={'amount_20': '20년도 평균', 'amount_21': '21년도 평균', 'total': '전체평균'})
amount_by_age.sort_values(by=list(amount_by_age.columns))
# Out:
#              20년도 평균    21년도 평균       전체평균
# age_cat
# sixties    1249915.0  1281572.0  2531487.0
# teenagers  1268363.0  1297362.0  2565725.0
# fifties    1274195.0  1308111.0  2582305.0
# forties    1278653.0  1257540.0  2536194.0
# thirties   1291444.0  1292349.0  2583793.0
# twenties   1293376.0  1278812.0  2572188.0
# seventies  1345964.0  1278015.0  2623978.0
# eighties   1400187.0  1264834.0  2665021.0

# %%
# 자녀들에게 돈 쓸 일이 많은 30-50대들의 평균이 높도록 / 20년도 보다 21년도가 높도록 수정
def more_amount(x):
    if x['age_cat'] in ['thirties','forties','fifties']:
        return x['amount_20'] * 1.2
    else:
        return x['amount_20'] * 0.5

def more_amount1(x):
    if x['age_cat'] in ['thirties','forties','fifties']:
        return x['amount_21'] * 1.5
    else:
        return x['amount_21']


merge_df['amount_20'] = merge_df.apply(lambda x : more_amount(x) if x['amount_20'] else x, axis=1)
merge_df['amount_21'] = merge_df.apply(lambda x : more_amount1(x) if x['amount_21'] else x, axis=1)

# %%
amount_by_age =merge_df.pivot_table(values=['amount_20', 'amount_21','total'], index='age_cat', aggfunc='mean').round()
amount_by_age=amount_by_age.rename(columns={'amount_20': '20년도 평균', 'amount_21': '21년도 평균', 'total': '전체평균'})
amount_by_age.sort_values(by=list(amount_by_age.columns))
# Out:
#              20년도 평균    21년도 평균       전체평균
# age_cat
# sixties     624957.0  1281572.0  2531487.0
# teenagers   634181.0  1297362.0  2565725.0
# twenties    646688.0  1278812.0  2572188.0
# seventies   672982.0  1278015.0  2623978.0
# eighties    700093.0  1264834.0  2665021.0
# fifties    1529034.0  1962166.0  2582305.0
# forties    1534384.0  1886311.0  2536194.0
# thirties   1549733.0  1938524.0  2583793.0

# %%
# 20/21년도 나잇대별로 그래프

# %%
# insight 2
# 상품별로 어느 고객층을 타깃으로 삼아야할지
# 상품별(고가,중가,저가) 성별 및 나이평균

merge_df.groupby(['product_20','gender']).age.mean().round()
# Out:
# product_20  gender
# 10          0         46.0
#             1         45.0
# 20          0         45.0
#             1         44.0
# 30          0         46.0
#             1         46.0
# Name: age, dtype: float64

# %%
merge_df.groupby(['product_21','gender']).age.mean().round()
# Out:
# product_21  gender
# 10          0         45.0
#             1         45.0
# 20          0         47.0
#             1         45.0
# 30          0         45.0
#             1         46.0
# Name: age, dtype: float64

# %%
# 고가 4-60 중가 2-30 저가 10,7-80대
# 고가와 중가는 50대쯤으로 비슷하게 중가의 연령대는 2-30대로 낮추기

# %%
# insight 3
# 요일 별 구매 금액
# 주말이 평일보다 많다

mean_by_day = pd.pivot_table(merge_df, values=['amount_20','amount_21','total'],index=day, aggfunc = 'sum').round()
mean_by_day.sort_values(by=list(mean_by_day.columns))
# Out:
#               amount_20     amount_21         total
# Tuesday    1.755681e+09  1.767165e+09  3.522847e+09
# Friday     1.805592e+09  1.851219e+09  3.656811e+09
# Monday     1.830329e+09  1.805957e+09  3.636286e+09
# Thursday   1.843710e+09  1.885724e+09  3.729434e+09
# Wednesday  1.856151e+09  1.875521e+09  3.731672e+09
# Saturday   1.879940e+09  1.874971e+09  3.754911e+09
# Sunday     1.905966e+09  1.786113e+09  3.692079e+09

# %%
# insight 4
# 고객이 가장 많이 이용하는 시간대
merge_df.groupby(['time_20']).cusno.count().sort_values()
# Out:
# time_20
# 12    390
# 14    397
# 11    399
# 7     402
# 24    404
# 8     408
# 23    408
# 1     409
# 13    409
# 5     411
# 2     412
# 16    412
# 21    415
# 3     417
# 10    419
# 22    422
# 15    427
# 9     427
# 18    430
# 17    431
# 6     434
# 20    437
# 19    440
# 4     440
# Name: cusno, dtype: int64

# %%
# 시간대별로 성별/나이 평균
merge_df.groupby(['time_20','gender']).age.mean()
# Out:
# time_20  gender
# 1        0         44.231527
#          1         48.092233
# 2        0         43.539683
#          1         44.668161
# 3        0         46.374384
#          1         45.780374
# 4        0         44.808411
#          1         45.296460
# 5        0         45.119171
#          1         46.096330
# 6        0         45.172897
#          1         46.131818
# 7        0         45.390863
#          1         44.804878
# 8        0         45.214286
#          1         45.113208
# 9        0         47.630841
#          1         46.375587
# 10       0         46.899522
#          1         43.704762
# 11       0         46.251397
#          1         46.281818
# 12       0         44.894737
#          1         46.450000
# 13       0         46.440415
#          1         42.620370
# 14       0         45.696682
#          1         43.553763
# 15       0         44.300000
#          1         45.299539
# 16       0         48.119403
#          1         47.616114
# 17       0         44.765000
#          1         47.047619
# 18       0         43.995327
#          1         42.694444
# 19       0         44.688372
#          1         43.364444
# 20       0         46.210000
#          1         45.054852
# 21       0         46.505208
#          1         45.488789
# 22       0         46.159624
#          1         46.622010
# 23       0         46.604167
#          1         42.995370
# 24       0         45.447368
#          1         44.803738
# Name: age, dtype: float64

# %%
# 24,1~6 : 새벽, 6~12 오전, 12~18시 오후 , 18시 ~20시 저녁, 20시 ~ 24시 밤
# 밤에 가장 많고 그 다음에 저녁 나머지 순으로
# 시간 범주형 생성
bins = [1,6,12,18,20,24]
labels=['dawn','morning','afternoon','evening','night']
merge_df['time_cat20'] = pd.cut(merge_df['time_20'], bins=bins,labels=labels)

# %%
bins = [1,6,12,18,20,24]
labels=['dawn','morning','afternoon','evening','night']
merge_df['time_cat21'] = pd.cut(merge_df['time_21'], bins=bins,labels=labels)

# %%
age_by_time20 = merge_df.pivot_table(index='gender',columns=['time_cat20'],values='age',aggfunc='mean').round()
age_by_time20
# Out:
# time_cat20  dawn  morning  afternoon  evening  night
# gender
# 0           45.0     46.0       46.0     45.0   46.0
# 1           46.0     45.0       45.0     44.0   45.0

# %%
age_by_time21 = merge_df.pivot_table(index='gender',columns=['time_cat21'],values='age',aggfunc='mean').round()
age_by_time21
# Out:
# time_cat21  dawn  morning  afternoon  evening  night
# gender
# 0           46.0     45.0       46.0     47.0   45.0
# 1           46.0     45.0       45.0     46.0   45.0

# %%
# insight 5
# 어떤 시간대에 어떤 이벤트를 하면 좋을지를 알기 위해서
# 시간대별 연령층
merge_df.groupby('time_20').age.mean()
# Out:
# time_20
# 1     46.176039
# 2     44.150485
# 3     46.069544
# 4     45.059091
# 5     45.637470
# 6     45.658986
# 7     45.092040
# 8     45.161765
# 9     47.004684
# 10    45.298329
# 11    46.268170
# 12    45.692308
# 13    44.422983
# 14    44.692695
# 15    44.807963
# 16    47.861650
# 17    45.988399
# 18    43.341860
# 19    44.011364
# 20    45.583524
# 21    45.959036
# 22    46.388626
# 23    44.693627
# 24    45.106436
# Name: age, dtype: float64

# %%
merge_df.groupby('age_cat').time_20.mean()
# Out:
# age_cat
# teenagers    12.600146
# twenties     12.635385
# thirties     12.669225
# forties      12.229138
# fifties      12.468874
# sixties      12.433407
# seventies    12.647100
# eighties     12.302013
# Name: time_20, dtype: float64

# %%
merge_df.groupby('age_cat').time_21.mean()
# Out:
# age_cat
# teenagers    12.219956
# twenties     12.835385
# thirties     12.424285
# forties      12.597811
# fifties      12.855629
# sixties      12.254599
# seventies    12.524045
# eighties     12.395973
# Name: time_21, dtype: float64

# %%
# 몇월에 구매량이 많은지
merge_df['year'] = merge_df['date'].apply(lambda x : x.year)
merge_df['month']=merge_df['date'].apply(lambda x : x.month)
merge_df['days'] = merge_df['date'].apply(lambda x : x.day)

# %%
merge_df.groupby('year').quantity_20.sum()
# Out:
# year
# 2020    249889
# 2021    253286
# Name: quantity_20, dtype: int64

# %%
# date가 2020년도인건 quantity_21에 없도록 그 반대도 없도록 수정
merge_df.loc[merge_df['year'] == 2020, 'quantity_21'] = 0
merge_df.loc[merge_df['year'] == 2021, 'quantity_20'] = 0

# %%
# 연도별 달별 구매량
what_quantity = merge_df.pivot_table(index=['year','month'], values=['quantity_20', 'quantity_21'],aggfunc = 'sum')
what_quantity.sort_values(by=list(what_quantity.columns))
# Out:
#             quantity_20  quantity_21
# year month
# 2021 2                0        19888
#      10               0        20064
#      8                0        20806
#      4                0        21026
#      6                0        21275
#      12               0        21299
#      5                0        21435
#      1                0        21611
#      11               0        21908
#      7                0        22255
#      9                0        22483
#      3                0        22510
# 2020 1            19646            0
#      10           20002            0
#      7            20178            0
#      3            20395            0
#      4            20468            0
#      11           20727            0
#      6            21063            0
#      8            21202            0
#      12           21270            0
#      9            21461            0
#      5            21527            0
#      2            21950            0

# %%
# 연령별 나이 평균
merge_df.groupby('age_cat').age.mean()
# Out:
# age_cat
# teenagers    14.093227
# twenties     24.416154
# thirties     34.614794
# forties      44.903557
# fifties      54.481457
# sixties      64.743194
# seventies    74.730552
# eighties     80.000000
# Name: age, dtype: float64
